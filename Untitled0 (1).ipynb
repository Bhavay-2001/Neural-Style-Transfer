# %% [markdown]
# ## *NEURAL STYLE TRANSFER*

# %% [markdown]
# ### *Import the Model*

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg19 import VGG19

# %%
from tensorflow.keras import layers

model = VGG19(
    include_top = False,
    weights = 'imagenet',
    input_shape = (size,size,3)
)

for layer in model.layers:
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step

# %% [markdown]
# ### *Import Preprocessing Libraries and Helper Functions*

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### *Image Preprocess and Display*

# %%
size=150
def load_and_preprocess_image(image_path,size=size):
  img = tf.keras.preprocessing.image.load_img(image_path, target_size=(size,size))
  img = img_to_array(img)
  img = preprocess_input(img)
  img = np.expand_dims(img, axis=0)
  return img

# %%
def deprocess_image(x):
  x[:, :, 0] += 103.939 # value added to the first channel of the image to deprocess the it.
  x[:, :, 1] += 116.779 # value added to the second channel of the image to deprocess it.
  x[:, :, 2] += 123.68 # value added to the third channel of the image to deprocess it.
  x = x[:, :, ::-1]

  x = np.clip(x,0,255).astype('uint8')
  return x

def display_image(image):
  if len(image.shape) == 4:
    img = np.squeeze(image, axis=0)

  img = deprocess_image(img)

  plt.grid(False)
  plt.imshow(img)
  return

# %%
from google.colab import files
files.upload()

# %%
display_image(load_and_preprocess_image('/content/style.jpg',size))

# %%
files.upload()

# %%
display_image(load_and_preprocess_image('/content/Taj_Mahal.jpg'))

# %% [markdown]
# ### *Content and Style Model*

# %%
content_layer = 'block5_conv2'

style_layer = [
               'block1_conv1',
               'block3_conv1',
               'block5_conv1',]

content_model = Model(
    inputs = model.input,
    outputs = model.get_layer(content_layer).output
)

style_models = [Model(
    inputs = model.input,
    outputs = model.get_layer(layer).output) for layer in style_layer]

# %% [markdown]
# ### *Content Cost*

# %%
def content_cost(content,generated):
  a_C = content_model(content)
  a_G = content_model(generated)
  mse = tf.keras.losses.MeanSquaredError()
  cost = mse(a_C,a_G).numpy()
  return cost

# %% [markdown]
# ### *Gram Matrix*

# %%
def gram_matrix(A):
  n_C = tf.shape(A)[-1]
  A = tf.reshape(A, shape=(-1, n_C))
  n = tf.shape(A)[0]
  G = tf.matmul(A,A,transpose_a=True)
  return G / tf.cast(n, tf.float32)

# %% [markdown]
# ### *Style Cost*

# %%
weight = 1. / len(style_models)

def style_cost(style,generated):
  J_style = 0

  for style_model in style_models:
    a_S = style_model(style)
    a_G = style_model(generated)
    GS = gram_matrix(a_S)
    GG = gram_matrix(a_G)
    current_cost = tf.reduce_mean(tf.square(GS - GG))
    J_style += current_cost * weight

    J_style /= (size*size*len(style_models))
  return J_style

# %% [markdown]
# ### *Training Loop*

# %%
import time
generated_images = []

def training_loop(content_path, style_path, iterations=20, alpha=10., beta=100.):
  
  content = load_and_preprocess_image(content_path)
  style = load_and_preprocess_image(style_path)

  generated = tf.Variable(content, dtype=tf.float32)
  
  opt = tf.keras.optimizers.Adam(learning_rate=7.)

  best_cost = 1e12 + 0.1
  best_image = None

  start_time = time.time()

  for i in range(iterations):
    with tf.GradientTape() as tape:
      J_content = content_cost(content,generated)
      J_style = style_cost(style,generated)
      J_total = alpha * J_content + beta * J_style

    grads = tape.gradient(J_total, generated)
    opt.apply_gradients([(grads, generated)])

    if J_total < best_cost:
      best_cost = J_total
      best_image = generated.numpy()

    print("Cost at",i,":",J_total,"and time elapsed is",time.time()-start_time)
    generated_images.append(generated.numpy())

  return best_image

# %%
best_image = training_loop('/content/Taj_Mahal.jpg','/content/style.jpg',iterations=300)
# Out:
# Cost at 0 : tf.Tensor(66750.15, shape=(), dtype=float32) and time elapsed is 0.23772788047790527
# Cost at 1 : tf.Tensor(84892.01, shape=(), dtype=float32) and time elapsed is 0.44341254234313965
# Cost at 2 : tf.Tensor(92759.445, shape=(), dtype=float32) and time elapsed is 0.6322619915008545
# Cost at 3 : tf.Tensor(96452.53, shape=(), dtype=float32) and time elapsed is 0.8161680698394775
# Cost at 4 : tf.Tensor(99765.17, shape=(), dtype=float32) and time elapsed is 0.9998517036437988
# Cost at 5 : tf.Tensor(98087.22, shape=(), dtype=float32) and time elapsed is 1.1799309253692627
# Cost at 6 : tf.Tensor(95660.65, shape=(), dtype=float32) and time elapsed is 1.3603308200836182
# Cost at 7 : tf.Tensor(95495.664, shape=(), dtype=float32) and time elapsed is 1.5404627323150635
# Cost at 8 : tf.Tensor(97391.836, shape=(), dtype=float32) and time elapsed is 1.7191123962402344
# Cost at 9 : tf.Tensor(100283.445, shape=(), dtype=float32) and time elapsed is 1.89829421043396
# Cost at 10 : tf.Tensor(101923.695, shape=(), dtype=float32) and time elapsed is 2.0805110931396484
# Cost at 11 : tf.Tensor(101415.67, shape=(), dtype=float32) and time elapsed is 2.259298801422119
# Cost at 12 : tf.Tensor(100682.78, shape=(), dtype=float32) and time elapsed is 2.676921844482422
# Cost at 13 : tf.Tensor(100654.18, shape=(), dtype=float32) and time elapsed is 2.855166435241699
# Cost at 14 : tf.Tensor(101297.42, shape=(), dtype=float32) and time elapsed is 3.0358994007110596
# Cost at 15 : tf.Tensor(101951.92, shape=(), dtype=float32) and time elapsed is 3.2137417793273926
# Cost at 16 : tf.Tensor(101947.47, shape=(), dtype=float32) and time elapsed is 3.3907618522644043
# Cost at 17 : tf.Tensor(101374.7, shape=(), dtype=float32) and time elapsed is 3.568679094314575
# Cost at 18 : tf.Tensor(100918.98, shape=(), dtype=float32) and time elapsed is 3.746760129928589
# Cost at 19 : tf.Tensor(100851.414, shape=(), dtype=float32) and time elapsed is 3.9254446029663086
# Cost at 20 : tf.Tensor(101024.27, shape=(), dtype=float32) and time elapsed is 4.103760242462158
# Cost at 21 : tf.Tensor(100943.305, shape=(), dtype=float32) and time elapsed is 4.284336805343628
# Cost at 22 : tf.Tensor(100656.07, shape=(), dtype=float32) and time elapsed is 4.461317777633667
# Cost at 23 : tf.Tensor(100369.1, shape=(), dtype=float32) and time elapsed is 4.638230562210083
# Cost at 24 : tf.Tensor(100333.25, shape=(), dtype=float32) and time elapsed is 4.8173346519470215
# Cost at 25 : tf.Tensor(100474.6, shape=(), dtype=float32) and time elapsed is 4.995872497558594
# Cost at 26 : tf.Tensor(100500.96, shape=(), dtype=float32) and time elapsed is 5.175376653671265
# Cost at 27 : tf.Tensor(100221.234, shape=(), dtype=float32) and time elapsed is 5.351726770401001
# Cost at 28 : tf.Tensor(99950.234, shape=(), dtype=float32) and time elapsed is 5.530700206756592
# Cost at 29 : tf.Tensor(99930.914, shape=(), dtype=float32) and time elapsed is 5.712691068649292
# Cost at 30 : tf.Tensor(100138.01, shape=(), dtype=float32) and time elapsed is 5.890392780303955
# Cost at 31 : tf.Tensor(100122.41, shape=(), dtype=float32) and time elapsed is 6.0711259841918945
# Cost at 32 : tf.Tensor(99668.66, shape=(), dtype=float32) and time elapsed is 6.247988700866699
# Cost at 33 : tf.Tensor(99184.016, shape=(), dtype=float32) and time elapsed is 6.425025939941406
# Cost at 34 : tf.Tensor(99075.12, shape=(), dtype=float32) and time elapsed is 6.6051294803619385
# Cost at 35 : tf.Tensor(99300.05, shape=(), dtype=float32) and time elapsed is 6.785155296325684
# Cost at 36 : tf.Tensor(99422.984, shape=(), dtype=float32) and time elapsed is 6.9633283615112305
# Cost at 37 : tf.Tensor(99297.94, shape=(), dtype=float32) and time elapsed is 7.145723581314087
# Cost at 38 : tf.Tensor(99209.984, shape=(), dtype=float32) and time elapsed is 7.323732376098633
# Cost at 39 : tf.Tensor(99319.484, shape=(), dtype=float32) and time elapsed is 7.500699281692505
# Cost at 40 : tf.Tensor(99436.43, shape=(), dtype=float32) and time elapsed is 7.677794694900513
# Cost at 41 : tf.Tensor(99405.79, shape=(), dtype=float32) and time elapsed is 7.855165243148804
# Cost at 42 : tf.Tensor(99336.09, shape=(), dtype=float32) and time elapsed is 8.034729480743408
# Cost at 43 : tf.Tensor(99340.24, shape=(), dtype=float32) and time elapsed is 8.214730262756348
# Cost at 44 : tf.Tensor(99359.68, shape=(), dtype=float32) and time elapsed is 8.392748594284058
# Cost at 45 : tf.Tensor(99340.64, shape=(), dtype=float32) and time elapsed is 8.572297096252441
# Cost at 46 : tf.Tensor(99369.91, shape=(), dtype=float32) and time elapsed is 8.74994683265686
# Cost at 47 : tf.Tensor(99469.695, shape=(), dtype=float32) and time elapsed is 8.92846965789795
# Cost at 48 : tf.Tensor(99519.93, shape=(), dtype=float32) and time elapsed is 9.106458902359009
# Cost at 49 : tf.Tensor(99451.64, shape=(), dtype=float32) and time elapsed is 9.284181594848633
# Cost at 50 : tf.Tensor(99372.56, shape=(), dtype=float32) and time elapsed is 9.462555170059204
# Cost at 51 : tf.Tensor(99373.61, shape=(), dtype=float32) and time elapsed is 9.643583297729492
# Cost at 52 : tf.Tensor(99392.01, shape=(), dtype=float32) and time elapsed is 9.822395324707031
# Cost at 53 : tf.Tensor(99334.45, shape=(), dtype=float32) and time elapsed is 10.000813007354736
# Cost at 54 : tf.Tensor(99258.53, shape=(), dtype=float32) and time elapsed is 10.182775974273682
# Cost at 55 : tf.Tensor(99232.72, shape=(), dtype=float32) and time elapsed is 10.361887454986572
# Cost at 56 : tf.Tensor(99210.484, shape=(), dtype=float32) and time elapsed is 10.540624618530273
# Cost at 57 : tf.Tensor(99162.805, shape=(), dtype=float32) and time elapsed is 10.719453811645508
# Cost at 58 : tf.Tensor(99157.664, shape=(), dtype=float32) and time elapsed is 10.897218704223633
# Cost at 59 : tf.Tensor(99183.87, shape=(), dtype=float32) and time elapsed is 11.078971862792969
# Cost at 60 : tf.Tensor(99193.586, shape=(), dtype=float32) and time elapsed is 11.257048845291138
# Cost at 61 : tf.Tensor(99246.87, shape=(), dtype=float32) and time elapsed is 11.435050249099731
# Cost at 62 : tf.Tensor(99323.3, shape=(), dtype=float32) and time elapsed is 11.61305284500122
# Cost at 63 : tf.Tensor(99337.125, shape=(), dtype=float32) and time elapsed is 11.791045427322388
# Cost at 64 : tf.Tensor(99273.92, shape=(), dtype=float32) and time elapsed is 11.969701766967773
# Cost at 65 : tf.Tensor(99274.2, shape=(), dtype=float32) and time elapsed is 12.145950317382812
# Cost at 66 : tf.Tensor(99323.76, shape=(), dtype=float32) and time elapsed is 12.324074745178223
# Cost at 67 : tf.Tensor(99364.59, shape=(), dtype=float32) and time elapsed is 12.50304388999939
# Cost at 68 : tf.Tensor(99417.26, shape=(), dtype=float32) and time elapsed is 12.681354999542236
# Cost at 69 : tf.Tensor(99491.38, shape=(), dtype=float32) and time elapsed is 12.85869812965393
# Cost at 70 : tf.Tensor(99478.39, shape=(), dtype=float32) and time elapsed is 13.036482572555542
# Cost at 71 : tf.Tensor(99521.96, shape=(), dtype=float32) and time elapsed is 13.216578722000122
# Cost at 72 : tf.Tensor(99672.82, shape=(), dtype=float32) and time elapsed is 13.394060850143433
# Cost at 73 : tf.Tensor(99753.164, shape=(), dtype=float32) and time elapsed is 13.57318377494812
# Cost at 74 : tf.Tensor(99752.01, shape=(), dtype=float32) and time elapsed is 13.75471544265747
# Cost at 75 : tf.Tensor(99838.336, shape=(), dtype=float32) and time elapsed is 13.934571504592896
# Cost at 76 : tf.Tensor(99934.37, shape=(), dtype=float32) and time elapsed is 14.111903190612793
# Cost at 77 : tf.Tensor(100019.13, shape=(), dtype=float32) and time elapsed is 14.290882110595703
# Cost at 78 : tf.Tensor(100103.3, shape=(), dtype=float32) and time elapsed is 14.46867561340332
# Cost at 79 : tf.Tensor(100146.11, shape=(), dtype=float32) and time elapsed is 14.646657705307007
# Cost at 80 : tf.Tensor(100144.68, shape=(), dtype=float32) and time elapsed is 14.82710886001587
# Cost at 81 : tf.Tensor(100152.9, shape=(), dtype=float32) and time elapsed is 15.004220008850098
# Cost at 82 : tf.Tensor(100164.08, shape=(), dtype=float32) and time elapsed is 15.18283987045288
# Cost at 83 : tf.Tensor(100159.35, shape=(), dtype=float32) and time elapsed is 15.361557483673096
# Cost at 84 : tf.Tensor(100119.945, shape=(), dtype=float32) and time elapsed is 15.539197444915771
# Cost at 85 : tf.Tensor(100169.56, shape=(), dtype=float32) and time elapsed is 15.717297554016113
# Cost at 86 : tf.Tensor(100235.59, shape=(), dtype=float32) and time elapsed is 15.894410371780396
# Cost at 87 : tf.Tensor(100243.71, shape=(), dtype=float32) and time elapsed is 16.073749780654907
# Cost at 88 : tf.Tensor(100263.016, shape=(), dtype=float32) and time elapsed is 16.257219791412354
# Cost at 89 : tf.Tensor(100258.68, shape=(), dtype=float32) and time elapsed is 16.435230493545532
# Cost at 90 : tf.Tensor(100266.57, shape=(), dtype=float32) and time elapsed is 16.61583948135376
# Cost at 91 : tf.Tensor(100323.11, shape=(), dtype=float32) and time elapsed is 16.795730113983154
# Cost at 92 : tf.Tensor(100341.46, shape=(), dtype=float32) and time elapsed is 16.9744131565094
# Cost at 93 : tf.Tensor(100367.47, shape=(), dtype=float32) and time elapsed is 17.152863264083862
# Cost at 94 : tf.Tensor(100400.016, shape=(), dtype=float32) and time elapsed is 17.33551287651062
# Cost at 95 : tf.Tensor(100425.766, shape=(), dtype=float32) and time elapsed is 17.514313220977783
# Cost at 96 : tf.Tensor(100480.984, shape=(), dtype=float32) and time elapsed is 17.693310022354126
# Cost at 97 : tf.Tensor(100511.86, shape=(), dtype=float32) and time elapsed is 17.871948719024658
# Cost at 98 : tf.Tensor(100526.51, shape=(), dtype=float32) and time elapsed is 18.05068325996399
# Cost at 99 : tf.Tensor(100559.36, shape=(), dtype=float32) and time elapsed is 18.228829622268677
# Cost at 100 : tf.Tensor(100575.086, shape=(), dtype=float32) and time elapsed is 18.407410144805908
# Cost at 101 : tf.Tensor(100601.11, shape=(), dtype=float32) and time elapsed is 18.584831476211548
# Cost at 102 : tf.Tensor(100629.9, shape=(), dtype=float32) and time elapsed is 18.762317419052124
# Cost at 103 : tf.Tensor(100652.02, shape=(), dtype=float32) and time elapsed is 18.939768075942993
# Cost at 104 : tf.Tensor(100684.695, shape=(), dtype=float32) and time elapsed is 19.122905731201172
# Cost at 105 : tf.Tensor(100707.49, shape=(), dtype=float32) and time elapsed is 19.300234079360962
# Cost at 106 : tf.Tensor(100730.195, shape=(), dtype=float32) and time elapsed is 19.480396509170532
# Cost at 107 : tf.Tensor(100741.18, shape=(), dtype=float32) and time elapsed is 19.658668279647827
# Cost at 108 : tf.Tensor(100715.19, shape=(), dtype=float32) and time elapsed is 19.83772325515747
# Cost at 109 : tf.Tensor(100750.01, shape=(), dtype=float32) and time elapsed is 20.01508855819702
# Cost at 110 : tf.Tensor(100777.2, shape=(), dtype=float32) and time elapsed is 20.191550970077515
# Cost at 111 : tf.Tensor(100766.84, shape=(), dtype=float32) and time elapsed is 20.372509956359863
# Cost at 112 : tf.Tensor(100810.71, shape=(), dtype=float32) and time elapsed is 20.551434755325317
# Cost at 113 : tf.Tensor(100805.51, shape=(), dtype=float32) and time elapsed is 20.728506565093994
# Cost at 114 : tf.Tensor(100795.766, shape=(), dtype=float32) and time elapsed is 20.905324935913086
# Cost at 115 : tf.Tensor(100831.14, shape=(), dtype=float32) and time elapsed is 21.083697080612183
# Cost at 116 : tf.Tensor(100808.98, shape=(), dtype=float32) and time elapsed is 21.2629177570343
# Cost at 117 : tf.Tensor(100822.75, shape=(), dtype=float32) and time elapsed is 21.443933486938477
# Cost at 118 : tf.Tensor(100881.15, shape=(), dtype=float32) and time elapsed is 21.624022960662842
# Cost at 119 : tf.Tensor(100861.32, shape=(), dtype=float32) and time elapsed is 21.80205273628235
# Cost at 120 : tf.Tensor(100884.72, shape=(), dtype=float32) and time elapsed is 21.98282790184021
# Cost at 121 : tf.Tensor(100894.31, shape=(), dtype=float32) and time elapsed is 22.159820318222046
# Cost at 122 : tf.Tensor(100880.164, shape=(), dtype=float32) and time elapsed is 22.337619304656982
# Cost at 123 : tf.Tensor(100894.73, shape=(), dtype=float32) and time elapsed is 22.51707124710083
# Cost at 124 : tf.Tensor(100892.375, shape=(), dtype=float32) and time elapsed is 22.695324182510376
# Cost at 125 : tf.Tensor(100916.56, shape=(), dtype=float32) and time elapsed is 22.8791024684906
# Cost at 126 : tf.Tensor(100919.89, shape=(), dtype=float32) and time elapsed is 23.05705165863037
# Cost at 127 : tf.Tensor(100896.04, shape=(), dtype=float32) and time elapsed is 23.23511815071106
# Cost at 128 : tf.Tensor(100882.43, shape=(), dtype=float32) and time elapsed is 23.413124799728394
# Cost at 129 : tf.Tensor(100902.51, shape=(), dtype=float32) and time elapsed is 23.592222452163696
# Cost at 130 : tf.Tensor(100944.32, shape=(), dtype=float32) and time elapsed is 23.768857717514038
# Cost at 131 : tf.Tensor(100888.695, shape=(), dtype=float32) and time elapsed is 23.945440530776978
# Cost at 132 : tf.Tensor(100863.29, shape=(), dtype=float32) and time elapsed is 24.12398672103882
# Cost at 133 : tf.Tensor(100878.21, shape=(), dtype=float32) and time elapsed is 24.303516149520874
# Cost at 134 : tf.Tensor(100916.49, shape=(), dtype=float32) and time elapsed is 24.482038021087646
# Cost at 135 : tf.Tensor(100956.99, shape=(), dtype=float32) and time elapsed is 24.66069269180298
# Cost at 136 : tf.Tensor(100908.266, shape=(), dtype=float32) and time elapsed is 24.83810806274414
# Cost at 137 : tf.Tensor(100975.34, shape=(), dtype=float32) and time elapsed is 25.016177892684937
# Cost at 138 : tf.Tensor(101001.766, shape=(), dtype=float32) and time elapsed is 25.19432282447815
# Cost at 139 : tf.Tensor(100955.86, shape=(), dtype=float32) and time elapsed is 25.37269687652588
# Cost at 140 : tf.Tensor(101012.08, shape=(), dtype=float32) and time elapsed is 25.55220317840576
# Cost at 141 : tf.Tensor(100976.336, shape=(), dtype=float32) and time elapsed is 25.730318546295166
# Cost at 142 : tf.Tensor(101062.82, shape=(), dtype=float32) and time elapsed is 25.913880586624146
# Cost at 143 : tf.Tensor(100943.52, shape=(), dtype=float32) and time elapsed is 26.091965198516846
# Cost at 144 : tf.Tensor(101004.71, shape=(), dtype=float32) and time elapsed is 26.270068645477295
# Cost at 145 : tf.Tensor(100982.99, shape=(), dtype=float32) and time elapsed is 26.44786500930786
# Cost at 146 : tf.Tensor(101019.2, shape=(), dtype=float32) and time elapsed is 26.626469612121582
# Cost at 147 : tf.Tensor(101061.46, shape=(), dtype=float32) and time elapsed is 26.80389952659607
# Cost at 148 : tf.Tensor(101027.77, shape=(), dtype=float32) and time elapsed is 26.99451780319214
# Cost at 149 : tf.Tensor(101137.59, shape=(), dtype=float32) and time elapsed is 27.173561811447144
# Cost at 150 : tf.Tensor(101039.49, shape=(), dtype=float32) and time elapsed is 27.351324558258057
# Cost at 151 : tf.Tensor(101116.125, shape=(), dtype=float32) and time elapsed is 27.530447006225586
# Cost at 152 : tf.Tensor(101038.24, shape=(), dtype=float32) and time elapsed is 27.70998215675354
# Cost at 153 : tf.Tensor(101095.8, shape=(), dtype=float32) and time elapsed is 27.88758420944214
# Cost at 154 : tf.Tensor(101084.195, shape=(), dtype=float32) and time elapsed is 28.068952322006226
# Cost at 155 : tf.Tensor(101050.336, shape=(), dtype=float32) and time elapsed is 28.247730493545532
# Cost at 156 : tf.Tensor(101144.75, shape=(), dtype=float32) and time elapsed is 28.42440962791443
# Cost at 157 : tf.Tensor(101029.375, shape=(), dtype=float32) and time elapsed is 28.601231575012207
# Cost at 158 : tf.Tensor(101240.34, shape=(), dtype=float32) and time elapsed is 28.780359268188477
# Cost at 159 : tf.Tensor(100980.59, shape=(), dtype=float32) and time elapsed is 28.958481073379517
# Cost at 160 : tf.Tensor(101297.43, shape=(), dtype=float32) and time elapsed is 29.13629651069641
# Cost at 161 : tf.Tensor(100935.445, shape=(), dtype=float32) and time elapsed is 29.313456296920776
# Cost at 162 : tf.Tensor(101383.62, shape=(), dtype=float32) and time elapsed is 29.492332458496094
# Cost at 163 : tf.Tensor(100889.3, shape=(), dtype=float32) and time elapsed is 29.671058654785156
# Cost at 164 : tf.Tensor(101518.17, shape=(), dtype=float32) and time elapsed is 29.848788261413574
# Cost at 165 : tf.Tensor(100853.01, shape=(), dtype=float32) and time elapsed is 30.02920436859131
# Cost at 166 : tf.Tensor(101564.66, shape=(), dtype=float32) and time elapsed is 30.208645820617676
# Cost at 167 : tf.Tensor(100832.414, shape=(), dtype=float32) and time elapsed is 30.388364553451538
# Cost at 168 : tf.Tensor(101537.62, shape=(), dtype=float32) and time elapsed is 30.5671226978302
# Cost at 169 : tf.Tensor(100805.086, shape=(), dtype=float32) and time elapsed is 30.745704412460327
# Cost at 170 : tf.Tensor(101450.445, shape=(), dtype=float32) and time elapsed is 30.924371480941772
# Cost at 171 : tf.Tensor(100972.49, shape=(), dtype=float32) and time elapsed is 31.103872537612915
# Cost at 172 : tf.Tensor(101319.34, shape=(), dtype=float32) and time elapsed is 31.280674934387207
# Cost at 173 : tf.Tensor(101184.086, shape=(), dtype=float32) and time elapsed is 31.45897150039673
# Cost at 174 : tf.Tensor(101187.88, shape=(), dtype=float32) and time elapsed is 31.63826894760132
# Cost at 175 : tf.Tensor(101335.05, shape=(), dtype=float32) and time elapsed is 31.81569743156433
# Cost at 176 : tf.Tensor(101022.62, shape=(), dtype=float32) and time elapsed is 31.997588872909546
# Cost at 177 : tf.Tensor(101511.59, shape=(), dtype=float32) and time elapsed is 32.17496132850647
# Cost at 178 : tf.Tensor(100758.87, shape=(), dtype=float32) and time elapsed is 32.35230565071106
# Cost at 179 : tf.Tensor(101849.45, shape=(), dtype=float32) and time elapsed is 32.53137969970703
# Cost at 180 : tf.Tensor(100386.46, shape=(), dtype=float32) and time elapsed is 32.709598779678345
# Cost at 181 : tf.Tensor(102207.625, shape=(), dtype=float32) and time elapsed is 32.88806104660034
# Cost at 182 : tf.Tensor(100315.664, shape=(), dtype=float32) and time elapsed is 33.06577658653259
# Cost at 183 : tf.Tensor(101700.72, shape=(), dtype=float32) and time elapsed is 33.24371552467346
# Cost at 184 : tf.Tensor(101257.91, shape=(), dtype=float32) and time elapsed is 33.42108750343323
# Cost at 185 : tf.Tensor(100639.46, shape=(), dtype=float32) and time elapsed is 33.59921884536743
# Cost at 186 : tf.Tensor(101913.586, shape=(), dtype=float32) and time elapsed is 33.777194023132324
# Cost at 187 : tf.Tensor(100653.43, shape=(), dtype=float32) and time elapsed is 33.95526456832886
# Cost at 188 : tf.Tensor(101354.21, shape=(), dtype=float32) and time elapsed is 34.133426666259766
# Cost at 189 : tf.Tensor(101471.4, shape=(), dtype=float32) and time elapsed is 34.31218099594116
# Cost at 190 : tf.Tensor(100622.59, shape=(), dtype=float32) and time elapsed is 34.49098801612854
# Cost at 191 : tf.Tensor(101735.23, shape=(), dtype=float32) and time elapsed is 34.669938802719116
# Cost at 192 : tf.Tensor(100776.22, shape=(), dtype=float32) and time elapsed is 34.84892678260803
# Cost at 193 : tf.Tensor(101161.49, shape=(), dtype=float32) and time elapsed is 35.028578758239746
# Cost at 194 : tf.Tensor(101429.59, shape=(), dtype=float32) and time elapsed is 35.207581758499146
# Cost at 195 : tf.Tensor(100644.87, shape=(), dtype=float32) and time elapsed is 35.38541054725647
# Cost at 196 : tf.Tensor(101612.055, shape=(), dtype=float32) and time elapsed is 35.56252384185791
# Cost at 197 : tf.Tensor(100860.12, shape=(), dtype=float32) and time elapsed is 35.74304223060608
# Cost at 198 : tf.Tensor(101128.08, shape=(), dtype=float32) and time elapsed is 35.923701763153076
# Cost at 199 : tf.Tensor(101359.74, shape=(), dtype=float32) and time elapsed is 36.10264730453491
# Cost at 200 : tf.Tensor(100749.4, shape=(), dtype=float32) and time elapsed is 36.28136849403381
# Cost at 201 : tf.Tensor(101579.19, shape=(), dtype=float32) and time elapsed is 36.45893311500549
# Cost at 202 : tf.Tensor(100787.0, shape=(), dtype=float32) and time elapsed is 36.638784885406494
# Cost at 203 : tf.Tensor(101320.81, shape=(), dtype=float32) and time elapsed is 36.81715393066406
# Cost at 204 : tf.Tensor(101220.85, shape=(), dtype=float32) and time elapsed is 36.995465993881226
# Cost at 205 : tf.Tensor(100915.19, shape=(), dtype=float32) and time elapsed is 37.17435431480408
# Cost at 206 : tf.Tensor(101503.78, shape=(), dtype=float32) and time elapsed is 37.35217642784119
# Cost at 207 : tf.Tensor(100727.414, shape=(), dtype=float32) and time elapsed is 37.53157353401184
# Cost at 208 : tf.Tensor(101598.76, shape=(), dtype=float32) and time elapsed is 37.713263511657715
# Cost at 209 : tf.Tensor(100710.13, shape=(), dtype=float32) and time elapsed is 37.89611744880676
# Cost at 210 : tf.Tensor(101501.1, shape=(), dtype=float32) and time elapsed is 38.0753960609436
# Cost at 211 : tf.Tensor(100836.05, shape=(), dtype=float32) and time elapsed is 38.25470685958862
# Cost at 212 : tf.Tensor(101222.3, shape=(), dtype=float32) and time elapsed is 38.433269739151
# Cost at 213 : tf.Tensor(101127.19, shape=(), dtype=float32) and time elapsed is 38.611661434173584
# Cost at 214 : tf.Tensor(101020.62, shape=(), dtype=float32) and time elapsed is 38.795862913131714
# Cost at 215 : tf.Tensor(101411.83, shape=(), dtype=float32) and time elapsed is 38.97431230545044
# Cost at 216 : tf.Tensor(100918.64, shape=(), dtype=float32) and time elapsed is 39.153542041778564
# Cost at 217 : tf.Tensor(101676.07, shape=(), dtype=float32) and time elapsed is 39.33137011528015
# Cost at 218 : tf.Tensor(100727.68, shape=(), dtype=float32) and time elapsed is 39.51014566421509
# Cost at 219 : tf.Tensor(101947.375, shape=(), dtype=float32) and time elapsed is 39.68815732002258
# Cost at 220 : tf.Tensor(100527.88, shape=(), dtype=float32) and time elapsed is 39.86792039871216
# Cost at 221 : tf.Tensor(102089.516, shape=(), dtype=float32) and time elapsed is 40.04735827445984
# Cost at 222 : tf.Tensor(100570.93, shape=(), dtype=float32) and time elapsed is 40.225502014160156
# Cost at 223 : tf.Tensor(101905.43, shape=(), dtype=float32) and time elapsed is 40.40404510498047
# Cost at 224 : tf.Tensor(101088.125, shape=(), dtype=float32) and time elapsed is 40.58417797088623
# Cost at 225 : tf.Tensor(101187.6, shape=(), dtype=float32) and time elapsed is 40.763296604156494
# Cost at 226 : tf.Tensor(101753.87, shape=(), dtype=float32) and time elapsed is 40.94289708137512
# Cost at 227 : tf.Tensor(100725.89, shape=(), dtype=float32) and time elapsed is 41.119402170181274
# Cost at 228 : tf.Tensor(101991.984, shape=(), dtype=float32) and time elapsed is 41.29878067970276
# Cost at 229 : tf.Tensor(100803.1, shape=(), dtype=float32) and time elapsed is 41.47759437561035
# Cost at 230 : tf.Tensor(101680.09, shape=(), dtype=float32) and time elapsed is 41.6570885181427
# Cost at 231 : tf.Tensor(101284.54, shape=(), dtype=float32) and time elapsed is 41.84016942977905
# Cost at 232 : tf.Tensor(101149.21, shape=(), dtype=float32) and time elapsed is 42.01882576942444
# Cost at 233 : tf.Tensor(101768.77, shape=(), dtype=float32) and time elapsed is 42.19936013221741
# Cost at 234 : tf.Tensor(100888.66, shape=(), dtype=float32) and time elapsed is 42.37749218940735
# Cost at 235 : tf.Tensor(101902.305, shape=(), dtype=float32) and time elapsed is 42.55638360977173
# Cost at 236 : tf.Tensor(100849.12, shape=(), dtype=float32) and time elapsed is 42.7359185218811
# Cost at 237 : tf.Tensor(101658.88, shape=(), dtype=float32) and time elapsed is 42.918325901031494
# Cost at 238 : tf.Tensor(101161.734, shape=(), dtype=float32) and time elapsed is 43.09785342216492
# Cost at 239 : tf.Tensor(101232.98, shape=(), dtype=float32) and time elapsed is 43.27563667297363
# Cost at 240 : tf.Tensor(101520.16, shape=(), dtype=float32) and time elapsed is 43.45456147193909
# Cost at 241 : tf.Tensor(100931.91, shape=(), dtype=float32) and time elapsed is 43.633885622024536
# Cost at 242 : tf.Tensor(101813.09, shape=(), dtype=float32) and time elapsed is 43.81273317337036
# Cost at 243 : tf.Tensor(100814.13, shape=(), dtype=float32) and time elapsed is 43.99083423614502
# Cost at 244 : tf.Tensor(101923.195, shape=(), dtype=float32) and time elapsed is 44.169246435165405
# Cost at 245 : tf.Tensor(100880.36, shape=(), dtype=float32) and time elapsed is 44.34718418121338
# Cost at 246 : tf.Tensor(101764.18, shape=(), dtype=float32) and time elapsed is 44.52599596977234
# Cost at 247 : tf.Tensor(101110.14, shape=(), dtype=float32) and time elapsed is 44.705646991729736
# Cost at 248 : tf.Tensor(101357.7, shape=(), dtype=float32) and time elapsed is 44.883317947387695
# Cost at 249 : tf.Tensor(101494.07, shape=(), dtype=float32) and time elapsed is 45.06366562843323
# Cost at 250 : tf.Tensor(100974.34, shape=(), dtype=float32) and time elapsed is 45.246588945388794
# Cost at 251 : tf.Tensor(101837.62, shape=(), dtype=float32) and time elapsed is 45.42358756065369
# Cost at 252 : tf.Tensor(100728.414, shape=(), dtype=float32) and time elapsed is 45.60087442398071
# Cost at 253 : tf.Tensor(102143.55, shape=(), dtype=float32) and time elapsed is 45.77924346923828
# Cost at 254 : tf.Tensor(100471.73, shape=(), dtype=float32) and time elapsed is 45.95833492279053
# Cost at 255 : tf.Tensor(102235.67, shape=(), dtype=float32) and time elapsed is 46.14073419570923
# Cost at 256 : tf.Tensor(100701.55, shape=(), dtype=float32) and time elapsed is 46.31983518600464
# Cost at 257 : tf.Tensor(101522.42, shape=(), dtype=float32) and time elapsed is 46.49741220474243
# Cost at 258 : tf.Tensor(101555.32, shape=(), dtype=float32) and time elapsed is 46.677998781204224
# Cost at 259 : tf.Tensor(100730.445, shape=(), dtype=float32) and time elapsed is 46.856749296188354
# Cost at 260 : tf.Tensor(102071.586, shape=(), dtype=float32) and time elapsed is 47.03671216964722
# Cost at 261 : tf.Tensor(100673.77, shape=(), dtype=float32) and time elapsed is 47.21509504318237
# Cost at 262 : tf.Tensor(101818.68, shape=(), dtype=float32) and time elapsed is 47.393240451812744
# Cost at 263 : tf.Tensor(101265.195, shape=(), dtype=float32) and time elapsed is 47.57237792015076
# Cost at 264 : tf.Tensor(101119.54, shape=(), dtype=float32) and time elapsed is 47.75031805038452
# Cost at 265 : tf.Tensor(101793.65, shape=(), dtype=float32) and time elapsed is 47.927170276641846
# Cost at 266 : tf.Tensor(100683.414, shape=(), dtype=float32) and time elapsed is 48.11028170585632
# Cost at 267 : tf.Tensor(101957.38, shape=(), dtype=float32) and time elapsed is 48.29182505607605
# Cost at 268 : tf.Tensor(100634.64, shape=(), dtype=float32) and time elapsed is 48.471166133880615
# Cost at 269 : tf.Tensor(101730.8, shape=(), dtype=float32) and time elapsed is 48.65149927139282
# Cost at 270 : tf.Tensor(101062.37, shape=(), dtype=float32) and time elapsed is 48.83037734031677
# Cost at 271 : tf.Tensor(101150.5, shape=(), dtype=float32) and time elapsed is 49.01091718673706
# Cost at 272 : tf.Tensor(101598.65, shape=(), dtype=float32) and time elapsed is 49.189239740371704
# Cost at 273 : tf.Tensor(100744.52, shape=(), dtype=float32) and time elapsed is 49.367042541503906
# Cost at 274 : tf.Tensor(101808.6, shape=(), dtype=float32) and time elapsed is 49.54790782928467
# Cost at 275 : tf.Tensor(100689.15, shape=(), dtype=float32) and time elapsed is 49.726577281951904
# Cost at 276 : tf.Tensor(101787.03, shape=(), dtype=float32) and time elapsed is 49.90499305725098
# Cost at 277 : tf.Tensor(100928.47, shape=(), dtype=float32) and time elapsed is 50.086379051208496
# Cost at 278 : tf.Tensor(101403.914, shape=(), dtype=float32) and time elapsed is 50.2666552066803
# Cost at 279 : tf.Tensor(101407.47, shape=(), dtype=float32) and time elapsed is 50.445658922195435
# Cost at 280 : tf.Tensor(100930.98, shape=(), dtype=float32) and time elapsed is 50.62527585029602
# Cost at 281 : tf.Tensor(101726.03, shape=(), dtype=float32) and time elapsed is 50.80297660827637
# Cost at 282 : tf.Tensor(100766.3, shape=(), dtype=float32) and time elapsed is 50.980628967285156
# Cost at 283 : tf.Tensor(101905.24, shape=(), dtype=float32) and time elapsed is 51.157421350479126
# Cost at 284 : tf.Tensor(100692.17, shape=(), dtype=float32) and time elapsed is 51.341949224472046
# Cost at 285 : tf.Tensor(101834.39, shape=(), dtype=float32) and time elapsed is 51.521156787872314
# Cost at 286 : tf.Tensor(100962.06, shape=(), dtype=float32) and time elapsed is 51.69891858100891
# Cost at 287 : tf.Tensor(101362.62, shape=(), dtype=float32) and time elapsed is 51.87887096405029
# Cost at 288 : tf.Tensor(101346.95, shape=(), dtype=float32) and time elapsed is 52.06092429161072
# Cost at 289 : tf.Tensor(100906.48, shape=(), dtype=float32) and time elapsed is 52.239859104156494
# Cost at 290 : tf.Tensor(101675.805, shape=(), dtype=float32) and time elapsed is 52.41867017745972
# Cost at 291 : tf.Tensor(100696.13, shape=(), dtype=float32) and time elapsed is 52.5980966091156
# Cost at 292 : tf.Tensor(101888.59, shape=(), dtype=float32) and time elapsed is 52.77610397338867
# Cost at 293 : tf.Tensor(100651.52, shape=(), dtype=float32) and time elapsed is 52.95425868034363
# Cost at 294 : tf.Tensor(101770.39, shape=(), dtype=float32) and time elapsed is 53.13969039916992
# Cost at 295 : tf.Tensor(100925.56, shape=(), dtype=float32) and time elapsed is 53.32717776298523
# Cost at 296 : tf.Tensor(101432.56, shape=(), dtype=float32) and time elapsed is 53.50624942779541
# Cost at 297 : tf.Tensor(101231.98, shape=(), dtype=float32) and time elapsed is 53.68435740470886
# Cost at 298 : tf.Tensor(101087.266, shape=(), dtype=float32) and time elapsed is 53.866950273513794
# Cost at 299 : tf.Tensor(101519.84, shape=(), dtype=float32) and time elapsed is 54.04597234725952

# %% [markdown]
# ### *Plot the Results*

# %%
image = display_image(best_image)
plt.savefig('/content/Modified_image.jpeg')

# %%
plt.figure(figsize=(30,30))

for i in range(100):
  plt.subplot(10, 10, i+1)
  display_image(generated_images[i])

plt.show()
